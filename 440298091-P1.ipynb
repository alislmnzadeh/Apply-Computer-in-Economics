# %% [markdown]
# <p style='color:dark green;font-size:2.1em;text-align:center;direction:rtl;font-family:B koodak'>پروژه شماره یک</p>

# %% [markdown]
# <p style='color:red;font-size:2.1em;text-align:center;direction:rtl;font-family:B koodak'>سوال 1</p>

# %%
file=open('scores.csv','r')
scores=file.read()
scores=scores.splitlines()
scores=scores[1:71]
scores=list(map(int,scores))
n1=0
n2=0
sum1=0
A=0
sum2=0
for i in range(0,70):
    sum1+=scores[i]
    a=scores[i]**2/70
    A+=a
    if scores[i]<10:
        n1+=1
ave1=sum1/70 
var=(A)-(ave1**2)
import math
dev=math.sqrt(var)
print('Sum:',sum1)
print ('Average:',ave1)
print('Standard Dev.:',dev)     
print ('Students Under10:',n1)
for i in range (0,70):
    zi=(scores[i]-ave1)/dev
    scores[i]=((10/5)*zi)+15
    if scores[i]>20:
        scores[i]=20
    if scores[i]<10:
        n+=1
    print(scores[i])
print('Students Under10 after process:',n2)
# Out:
# Sum: 815
# Average: 11.642857142857142
# Standard Dev.: 2.236296136061402
# Students Under10: 11
# 15.319405691745157
# 15.319405691745157
# 14.425069754858718
# 16.2137416286316
# 13.530733817972278
# 13.530733817972278
# 15.319405691745157
# 13.530733817972278
# 12.636397881085838
# 17.108077565518037
# 16.2137416286316
# 15.319405691745157
# 15.319405691745157
# 15.319405691745157
# 13.530733817972278
# 14.425069754858718
# 14.425069754858718
# 12.636397881085838
# 14.425069754858718
# 12.636397881085838
# 16.2137416286316
# 17.108077565518037
# 16.2137416286316
# 14.425069754858718
# 20
# 18.00241350240448
# 12.636397881085838
# 13.530733817972278
# 12.636397881085838
# 17.108077565518037
# 13.530733817972278
# 18.896749439290918
# 13.530733817972278
# 16.2137416286316
# 15.319405691745157
# 15.319405691745157
# 18.896749439290918
# 16.2137416286316
# 12.636397881085838
# 15.319405691745157
# 18.00241350240448
# 13.530733817972278
# 15.319405691745157
# 16.2137416286316
# ...

# %% [markdown]
# <p style='color:red;font-size:2.1em;text-align:center;direction:rtl;font-family:B koodak'>سوال 2</p>

# %%
file=open('midterm.csv','r')
midterm=file.read()
midterm=midterm.splitlines()
midterm=midterm[1:71]
midterm=list(map(int,midterm))
final=[]
for l in range(0,70):
    if scores[i]>=1.2*midterm[l]:
        a=scores[i]*0.7+midterm[l]*0.3
        final.append(a)
    else:
        b=scores[i]*0.6+midterm[l]*0.4
        final.append(b)
print(final)
# Out:
# [17.42772460750364, 17.73804966357455, 17.12772460750364, 17.73804966357455, 17.12772460750364, 18.13804966357455, 18.13804966357455, 17.12772460750364, 18.13804966357455, 18.53804966357455, 16.82772460750364, 17.42772460750364, 17.42772460750364, 17.42772460750364, 16.82772460750364, 17.42772460750364, 18.13804966357455, 17.12772460750364, 18.13804966357455, 18.13804966357455, 16.82772460750364, 17.12772460750364, 17.727724607503642, 17.73804966357455, 17.42772460750364, 18.53804966357455, 17.12772460750364, 17.42772460750364, 17.42772460750364, 16.82772460750364, 17.42772460750364, 17.42772460750364, 15.927724607503642, 18.93804966357455, 16.82772460750364, 17.73804966357455, 17.12772460750364, 17.42772460750364, 17.73804966357455, 18.13804966357455, 17.12772460750364, 17.42772460750364, 17.73804966357455, 17.73804966357455, 16.82772460750364, 17.12772460750364, 17.42772460750364, 17.727724607503642, 17.727724607503642, 17.12772460750364, 16.82772460750364, 16.527724607503643, 16.8
# ...

# %% [markdown]
# <p style='color:red;font-size:2.1em;text-align:center;direction:rtl;font-family:B koodak'>سوال 3</p>

# %%
file=open('names.csv','r')
names=file.read()
names=names.splitlines()
names=names[1:71]
for z in range (0,70):
    names[z]=names[z].capitalize()
fin1={}
tup3=()
tup4=[]
tup3=names+final
key=[j for j in range (1,71)]
for i in range(0,70):
    tup4.append((names[i],final[i]))    
for l in range (0,70):
    fin1[key[l]]=tup4[l]
print (fin1)
# Out:
# {1: ('Amirhossein', 17.42772460750364), 2: ('Amirali', 17.73804966357455), 3: ('Mohammad', 17.12772460750364), 4: ('Elnaz', 17.73804966357455), 5: ('Nazanin', 17.12772460750364), 6: ('Ali', 18.13804966357455), 7: ('Hossein', 18.13804966357455), 8: ('Melika', 17.12772460750364), 9: ('Amirmohammad', 18.13804966357455), 10: ('Kiana', 18.53804966357455), 11: ('Aida', 16.82772460750364), 12: ('Parnia', 17.42772460750364), 13: ('Mohammadmahdi', 17.42772460750364), 14: ('Hananeh', 17.42772460750364), 15: ('Mohammadamin', 16.82772460750364), 16: ('Alireza', 17.42772460750364), 17: ('Amirreza', 18.13804966357455), 18: ('Taha', 17.12772460750364), 19: ('Haniyeh', 18.13804966357455), 20: ('Mahdis', 18.13804966357455), 21: ('Mahan', 16.82772460750364), 22: ('Yasin', 17.12772460750364), 23: ('Parsa', 17.727724607503642), 24: ('Asma', 17.73804966357455), 25: ('Kian', 17.42772460750364), 26: ('Hosna', 18.53804966357455), 27: ('Yasamin', 17.12772460750364), 28: ('Fatima', 17.42772460750364), 29: ('A
# ...

# %% [markdown]
# <p style='color:red;font-size:2.1em;text-align:center;direction:rtl;font-family:B koodak'>سوال 4</p>

# %%
alphabet=str(input())
alphabet=alphabet.capitalize()
for l in range (0,70):
    if alphabet in fin1[key[l]][0][0]:
        print (fin1[key[l]])
# Out:
# a
# ('Amirhossein', 17.42772460750364)
# ('Amirali', 17.73804966357455)
# ('Ali', 18.13804966357455)
# ('Amirmohammad', 18.13804966357455)
# ('Aida', 16.82772460750364)
# ('Alireza', 17.42772460750364)
# ('Amirreza', 18.13804966357455)
# ('Asma', 17.73804966357455)
# ('Atena', 17.42772460750364)
# ('Artin', 17.12772460750364)
# ('Armin', 17.42772460750364)
# ('Aynar', 17.73804966357455)
# ('Asal', 20)
# ('Arya', 17.73804966357455)
# ('Arad', 17.727724607503642)
# ('Arash', 16.82772460750364)
# ('Aliakbar', 20)
# ('Ava', 17.42772460750364)
# ('Abbas', 17.42772460750364)
# ('Amin', 17.42772460750364)
# ('Arman', 17.73804966357455)
# ('Aref', 17.727724607503642)
# ('Ahmad', 17.727724607503642)
# ('Asghar', 17.727724607503642)
# ('Akbar', 17.12772460750364)

# %% [markdown]
# <p style='color:red;font-size:2.1em;text-align:center;direction:rtl;font-family:B koodak'>سوال 5 قسمت اول</p>

# %%
for l in range(0,70):
    if names[l]=='Kiana':
        final[l]+=2
        if final [l]>20:
            final[l]=20
    if names[l]=='Kian':
        final[l]+=4
        if final [l]>20:
            final[l]=20
    if names[l]=='Hosna':
        final[l]+=1
        if final [l]>20:
            final[l]=20
    if names[l]=='Liya':
        final[l]+=1
        if final [l]>20:
            final[l]=20
    if names[l]=='Helia':
        final[l]+=2
        if final [l]>20:
            final[l]=20 
    if names[l]=='Asal':
        final[l]+=1
        if final [l]>20:
            final[l]=20
    if names[l]=='Aliakbar':
        final[l]+=3
        if final [l]>20:
            final[l]=20
print (final)
# Out:
# [17.42772460750364, 17.73804966357455, 17.12772460750364, 17.73804966357455, 17.12772460750364, 18.13804966357455, 18.13804966357455, 17.12772460750364, 18.13804966357455, 20, 16.82772460750364, 17.42772460750364, 17.42772460750364, 17.42772460750364, 16.82772460750364, 17.42772460750364, 18.13804966357455, 17.12772460750364, 18.13804966357455, 18.13804966357455, 16.82772460750364, 17.12772460750364, 17.727724607503642, 17.73804966357455, 20, 20, 17.12772460750364, 17.42772460750364, 17.42772460750364, 16.82772460750364, 17.42772460750364, 17.42772460750364, 15.927724607503642, 20, 16.82772460750364, 17.73804966357455, 17.12772460750364, 17.42772460750364, 17.73804966357455, 20, 17.12772460750364, 17.42772460750364, 17.73804966357455, 17.73804966357455, 16.82772460750364, 17.12772460750364, 17.42772460750364, 17.727724607503642, 17.727724607503642, 17.12772460750364, 16.82772460750364, 16.527724607503643, 16.82772460750364, 17.73804966357455, 20, 17.42772460750364, 17.73804966357455,
# ...

# %% [markdown]
# <p style='color:red;font-size:2.1em;text-align:center;direction:rtl;font-family:B koodak'>سوال 5 قسمت دوم</p>

# %%
tup3=()
tup4=[]
tup3=names+final
key=[j for j in range (1,71)]
for i in range(0,70):
    tup4.append((names[i],final[i]))    
for l in range (0,70):
    fin1[key[l]]=tup4[l]
print (fin1)
# Out:
# {1: ('Amirhossein', 17.42772460750364), 2: ('Amirali', 17.73804966357455), 3: ('Mohammad', 17.12772460750364), 4: ('Elnaz', 17.73804966357455), 5: ('Nazanin', 17.12772460750364), 6: ('Ali', 18.13804966357455), 7: ('Hossein', 18.13804966357455), 8: ('Melika', 17.12772460750364), 9: ('Amirmohammad', 18.13804966357455), 10: ('Kiana', 20), 11: ('Aida', 16.82772460750364), 12: ('Parnia', 17.42772460750364), 13: ('Mohammadmahdi', 17.42772460750364), 14: ('Hananeh', 17.42772460750364), 15: ('Mohammadamin', 16.82772460750364), 16: ('Alireza', 17.42772460750364), 17: ('Amirreza', 18.13804966357455), 18: ('Taha', 17.12772460750364), 19: ('Haniyeh', 18.13804966357455), 20: ('Mahdis', 18.13804966357455), 21: ('Mahan', 16.82772460750364), 22: ('Yasin', 17.12772460750364), 23: ('Parsa', 17.727724607503642), 24: ('Asma', 17.73804966357455), 25: ('Kian', 20), 26: ('Hosna', 20), 27: ('Yasamin', 17.12772460750364), 28: ('Fatima', 17.42772460750364), 29: ('Atena', 17.42772460750364), 30: ('Mohaddeseh',
# ...
